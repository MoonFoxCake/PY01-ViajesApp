# %%
from pymongo import MongoClient
from bson import ObjectId

client = MongoClient('mongodb://localhost:27017/', username='root', password='root')
db = client['SocialMedia']



db.Posts.insert_many(
    [
  {
    "_id": ObjectId("650a1b2c3d4e5f6789012345"),
    "Autor": "UserID template",
    "Texto": "Texto de la publicación",
    "Media": "URL de la imagen o video",
    "Likes": ["UserID template", "UserID template"],
    "Comentarios": [
        {
            "UserID": "UserID template",
            "Texto": "Texto del comentario"
        },
        {
            "UserID": "UserID template",
            "Texto": "Texto del comentario"
        }
    ],
  }
  
]

)


db.destinations.insert_many(
    [
  {
    "_id": ObjectId("aaaaaaaaaaaaaaaaaaaa"),
    "PlaceID": "ID del lugar",
    "Autor": "UserID template",
    "Destination Name": "Nombre del lugar",
    "Description": "Descripción del lugar",
    "Location": "Ubicación del lugar",
    "Likes": ["UserID template", "UserID template"],
    "Comentarios": [
        {
            "UserID": "UserID template",
            "Texto": "Texto del comentario"
        },
        {
            "UserID": "UserID template",
            "Texto": "Texto del comentario"
        }
    ],
  }
  
]

)

db.BucketLists.insert_many(
    [
  {
    "_id": ObjectId("aaaaaaaaaaaaaaaaaaaa"),
    "Autor": "UserID template",
    "Destinos": ["PlaceID", "PlaceID"],
    "Likes": ["UserID template", "UserID template"],
    "Comentarios": [
        {
            "UserID": "UserID template",
            "Texto": "Texto del comentario"
        },
        {
            "UserID": "UserID template",
            "Texto": "Texto del comentario"
        }
    ],
  }
  
]

)

db.trips.insert_many(
    [
  {
    "_id": ObjectId("aaaaaaaaaaaaaaaaaaaa"),
    "Participants": ["UserID template", "UserID template"],
    "Destinos": ["PlaceID", "PlaceID"],
    "Likes": ["UserID template", "UserID template"],
    "Comentarios": [
        {
            "UserID": "UserID template",
            "Texto": "Texto del comentario"
        },
        {
            "UserID": "UserID template",
            "Texto": "Texto del comentario"
        }
    ],
  }
  
]

)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       4 client = MongoClient('mongodb://localhost:27017/', username='root', password='root')
#       5 db = client['SocialMedia']
# ----> 9 db.Posts.insert_one(
#      10     [
#      11   {
#      12     "_id": ObjectId("650a1b2c3d4e5f6789012345"),
#      13     "Autor": "UserID template",
#      14     "Texto": "Texto de la publicación",
#      15     "Media": "URL de la imagen o video",
#      16     "Likes": ["UserID template", "UserID template"],
#      17     "Comentarios": [
#      18         {
#      19             "UserID": "UserID template",
#      20             "Texto": "Texto del comentario"
#      21         },
#      22         {
#      23             "UserID": "UserID template",
#      24             "Texto": "Texto del comentario"
#      25         }
#      26     ],
#      27   }
#      28
# ...
